# %%
# !python -V
# Out:
# Python 3.9.16

# %%
import pandas as pd

# %%
import pickle

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import mean_squared_error

# %%
import mlflow


mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# <Experiment: artifact_location='/Users/jojocao/Desktop/Study/zoomcamp/mlops-zoomcamp/02-experiment-tracking/mlruns/1', creation_time=1684978572949, experiment_id='1', last_update_time=1684978572949, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
def read_dataframe(filename):
    df = pd.read_parquet(filename)

    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe('data/green_tripdata_2021-01.parquet')
df_val = read_dataframe('data/green_tripdata_2021-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (73908, 61921)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 7.75871520559622

# %%
with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
with mlflow.start_run():

    mlflow.set_tag("developer", "cristian")

    mlflow.log_param("train-data-path", "./data/green_tripdata_2021-01.parquet")
    mlflow.log_param("valid-data-path", "./data/green_tripdata_2021-02.parquet")

    alpha = 0.1
    mlflow.log_param("alpha", alpha)
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    mlflow.log_artifact(local_path="models/lin_reg.bin", artifact_path="models_pickle")

# %%
import xgboost as xgb

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
# [09:40:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:18.93295
# [1]	validation-rmse:16.99119
# [2]	validation-rmse:15.32865
# [3]	validation-rmse:13.91118
# [4]	validation-rmse:12.70805
# [5]	validation-rmse:11.69129
# [6]	validation-rmse:10.83700
# [7]	validation-rmse:10.12116
# [8]	validation-rmse:9.52577
# [9]	validation-rmse:9.03101
# [10]	validation-rmse:8.62382
# [11]	validation-rmse:8.28920
# [12]	validation-rmse:8.01404
# [13]	validation-rmse:7.78829
# [14]	validation-rmse:7.60483
# [15]	validation-rmse:7.45207
# [16]	validation-rmse:7.32596
# [17]	validation-rmse:7.22345
# [18]	validation-rmse:7.13833
# [19]	validation-rmse:7.06786
# [20]	validation-rmse:7.00925
# [21]	validation-rmse:6.95949
# [22]	validation-rmse:6.91877
# [23]	validation-rmse:6.88307
# [24]	validation-rmse:6.85407
# [25]	validation-rmse:6.82928
# [26]	validation-rmse:6.80824
# [27]	validation-rmse:6.79000
# [28]	validation-rmse:6.77487
# [29]	validation-rmse:6.76061
# [30]	validation-rmse:6.74915
# [31]	validation-rmse:6.73941
# [32]	validation-rmse:6.73030
# [33]	validation-rmse:6.72185
# [34]	validation-rmse:6.71388
# [35]	validation-rmse:6.70742
# [36]	validation-rmse:6.70113
# [37]	validation-rmse:6.69615
# [38]	validation-rmse:6.69235
# [39]	validation-rmse:6.68834
# [40]	validation-rmse:6.68499
# [41]	validation-rmse:6.68222
# [42]	validation-rmse:6.67948
# [43]	validation-rmse:6.67692
# [44]	validation-rmse:6.67514
# [45]	validation-rmse:6.67332
# [46]	validation-rmse:6.67186
# [47]	validation-rmse:6.67056
# [48]	validation-rmse:6.66912
# [49]	validation-rmse:6.66815
# [50]	validation-rmse:6.66721
# [51]	validation-rmse:6.66614
# [52]	validation-rmse:6.66532
# [53]	validation-rmse:6.66464
# [54]	validation-rmse:6.66384
# [55]	validation-rmse:6.66300
# [56]	validation-rmse:6.66229
# [57]	validation-rmse:6.66172
# [58]	validation-rmse:6.66132
# [59]	validation-rmse:6.66095
# [60]	validation-rmse:6.66038
# [61]	validation-rmse:6.65997
# [62]	validation-rmse:6.65955
# [63]	validation-rmse:6.65904
# [64]	validation-rmse:6.65882
# [65]	validation-rmse:6.65838
# [66]	validation-rmse:6.65765
# [67]	validation-rmse:6.65754
# [68]	validation-rmse:6.65729
# [69]	validation-rmse:6.65715
# [70]	validation-rmse:6.65660
# [71]	validation-rmse:6.65645
# [72]	validation-rmse:6.65607
# [73]	validation-rmse:6.65564
# [74]	validation-rmse:6.65535
# [75]	validation-rmse:6.65501
# [76]	validation-rmse:6.65484
# [77]	validation-rmse:6.65477
# [78]	validation-rmse:6.65451
# [79]	validation-rmse:6.65426
# [80]	validation-rmse:6.65408
# [81]	validation-rmse:6.65389
# [82]	validation-rmse:6.65356
# [83]	validation-rmse:6.65326
# [84]	validation-rmse:6.65287
# [85]	validation-rmse:6.65258
# [86]	validation-rmse:6.65249
# [87]	validation-rmse:6.65235
# [88]	validation-rmse:6.65214
# [89]	validation-rmse:6.65196
# [90]	validation-rmse:6.65199
# [91]	validation-rmse:6.65176
# [92]	validation-rmse:6.65144
# [93]	validation-rmse:6.65120
# [94]	validation-rmse:6.65108
# [95]	validation-rmse:6.65084
# [96]	validation-rmse:6.65081
# [97]	validation-rmse:6.65072
# [98]	validation-rmse:6.65054
# [99]	validation-rmse:6.65051
# [100]	validation-rmse:6.65021
# [101]	validation-rmse:6.64988
# [102]	validation-rmse:6.64970
# [103]	validation-rmse:6.64970
# [104]	validation-rmse:6.64976
# [105]	validation-rmse:6.64966
# [106]	validation-rmse:6.64942
# [107]	validation-rmse:6.64924
# [108]	validation-rmse:6.64919
# [109]	validation-rmse:6.64907
# [110]	validation-rmse:6.64902
# [111]	validation-rmse:6.64895
# [112]	validation-rmse:6.64897
# [113]	validation-rmse:6.64875
# [114]	validation-rmse:6.64868
# [115]	validation-rmse:6.64842
# [116]	validation-rmse:6.64832
# [117]	validation-rmse:6.64794
# [118]	validation-rmse:6.64772
# [119]	validation-rmse:6.64759
# [120]	validation-rmse:6.64735
# [121]	validation-rmse:6.64732
# [122]	validation-rmse:6.64707
# [123]	validation-rmse:6.64720
# [124]	validation-rmse:6.64706
# [125]	validation-rmse:6.64696
# [126]	validation-rmse:6.64698
# [127]	validation-rmse:6.64701
# [128]	validation-rmse:6.64684
# [129]	validation-rmse:6.64658
# [130]	validation-rmse:6.64642
# [131]	validation-rmse:6.64648
# [132]	validation-rmse:6.64635
# [133]	validation-rmse:6.64606
# [134]	validation-rmse:6.64592
# [135]	validation-rmse:6.64579
# [136]	validation-rmse:6.64551
# [137]	validation-rmse:6.64546
# [138]	validation-rmse:6.64539
# [139]	validation-rmse:6.64540
# [140]	validation-rmse:6.64528
# [141]	validation-rmse:6.64524
# [142]	validation-rmse:6.64512
# [143]	validation-rmse:6.64492
# [144]	validation-rmse:6.64494
# [145]	validation-rmse:6.64490
# [146]	validation-rmse:6.64488
# [147]	validation-rmse:6.64471
# [148]	validation-rmse:6.64458
# [149]	validation-rmse:6.64455
# [150]	validation-rmse:6.64438
# [151]	validation-rmse:6.64425
# [152]	validation-rmse:6.64395
# [153]	validation-rmse:6.64374
# [154]	validation-rmse:6.64357
# [155]	validation-rmse:6.64349
# [156]	validation-rmse:6.64340
# [157]	validation-rmse:6.64328
# [158]	validation-rmse:6.64334
# [159]	validation-rmse:6.64315
# [160]	validation-rmse:6.64304
# [161]	validation-rmse:6.64308
# [162]	validation-rmse:6.64278
# [163]	validation-rmse:6.64263
# [164]	validation-rmse:6.64244
# [165]	validation-rmse:6.64242
# [166]	validation-rmse:6.64227
# [167]	validation-rmse:6.64218
# [168]	validation-rmse:6.64204
# [169]	validation-rmse:6.64207
# [170]	validation-rmse:6.64193
# [171]	validation-rmse:6.64186
# [172]	validation-rmse:6.64164
# [173]	validation-rmse:6.64178
# [174]	validation-rmse:6.64180
# [175]	validation-rmse:6.64171
# [176]	validation-rmse:6.64173
# [177]	validation-rmse:6.64150
# [178]	validation-rmse:6.64153
# [179]	validation-rmse:6.64130
# [180]	validation-rmse:6.64108
# [181]	validation-rmse:6.64100
# [182]	validation-rmse:6.64104
# [183]	validation-rmse:6.64085
# [184]	validation-rmse:6.64078
# [185]	validation-rmse:6.64067
# [186]	validation-rmse:6.64056
# [187]	validation-rmse:6.64040
# [188]	validation-rmse:6.64035
# [189]	validation-rmse:6.64027
# [190]	validation-rmse:6.64029
# [191]	validation-rmse:6.64004
# [192]	validation-rmse:6.63999
# [193]	validation-rmse:6.63980
# [194]	validation-rmse:6.63971
# [195]	validation-rmse:6.63978
# [196]	validation-rmse:6.63931
# [197]	validation-rmse:6.63922
# [198]	validation-rmse:6.63914
# [199]	validation-rmse:6.63916
# [200]	validation-rmse:6.63914
# [201]	validation-rmse:6.63912
# [202]	validation-rmse:6.63903
# [203]	validation-rmse:6.63890
# [204]	validation-rmse:6.63879
# [205]	validation-rmse:6.63869
# [206]	validation-rmse:6.63863
# [207]	validation-rmse:6.63875
# [208]	validation-rmse:6.63882
# [209]	validation-rmse:6.63870
# [210]	validation-rmse:6.63877
# [211]	validation-rmse:6.63876
# [212]	validation-rmse:6.63868
# [213]	validation-rmse:6.63872
# [214]	validation-rmse:6.63871
# [215]	validation-rmse:6.63853
# [216]	validation-rmse:6.63850
# [217]	validation-rmse:6.63837
# [218]	validation-rmse:6.63838
# [219]	validation-rmse:6.63831
# [220]	validation-rmse:6.63819
# [221]	validation-rmse:6.63811
# [222]	validation-rmse:6.63806
# [223]	validation-rmse:6.63804
# [224]	validation-rmse:6.63808
# [225]	validation-rmse:6.63802
# [226]	validation-rmse:6.63789
# [227]	validation-rmse:6.63754
# [228]	validation-rmse:6.63749
# [229]	validation-rmse:6.63743
# [230]	validation-rmse:6.63728
# [231]	validation-rmse:6.63718
# [232]	validation-rmse:6.63716
# [233]	validation-rmse:6.63713
# [234]	validation-rmse:6.63710
# [235]	validation-rmse:6.63710
# [236]	validation-rmse:6.63714
# [237]	validation-rmse:6.63728
# [238]	validation-rmse:6.63722
# [239]	validation-rmse:6.63721
# [240]	validation-rmse:6.63725
# [241]	validation-rmse:6.63715
# [242]	validation-rmse:6.63716
# [243]	validation-rmse:6.63709
# [244]	validation-rmse:6.63717
# [245]	validation-rmse:6.63721
# [246]	validation-rmse:6.63710
# [247]	validation-rmse:6.63687
# [248]	validation-rmse:6.63679
# [249]	validation-rmse:6.63651
# [250]	validation-rmse:6.63652
# [251]	validation-rmse:6.63651
# [252]	validation-rmse:6.63658
# [253]	validation-rmse:6.63643
# [254]	validation-rmse:6.63651
# [255]	validation-rmse:6.63655
# [256]	validation-rmse:6.63638
# [257]	validation-rmse:6.63632
# [258]	validation-rmse:6.63629
# [259]	validation-rmse:6.63630
# [260]	validation-rmse:6.63633
# [261]	validation-rmse:6.63617
# [262]	validation-rmse:6.63633
# [263]	validation-rmse:6.63629
# [264]	validation-rmse:6.63635
# [265]	validation-rmse:6.63629
# [266]	validation-rmse:6.63631
# [267]	validation-rmse:6.63632
# [268]	validation-rmse:6.63623
# [269]	validation-rmse:6.63623
# [270]	validation-rmse:6.63616
# [271]	validation-rmse:6.63621
# [272]	validation-rmse:6.63609
# [273]	validation-rmse:6.63603
# [274]	validation-rmse:6.63600
# [275]	validation-rmse:6.63583
# [276]	validation-rmse:6.63605
# [277]	validation-rmse:6.63615
# [278]	validation-rmse:6.63612
# [279]	validation-rmse:6.63627
#   0%|          | 0/50 [00:26<?, ?trial/s, best loss=?]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 11
#       1 search_space = {
#       2     'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
#       3     'learning_rate': hp.loguniform('learning_rate', -3, 0),
#    (...)
#       8     'seed': 42
#       9 }
# ---> 11 best_result = fmin(
#      12     fn=objective,
#      13     space=search_space,
#      14     algo=tpe.suggest,
#      15     max_evals=50,
#      16     trials=Trials()
#      17 )
#
# File ~/anaconda3/envs/mlops/lib/python3.9/site-packages/hyperopt/fmin.py:540, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     537     fn = __objective_fmin_wrapper(fn)
#     539 if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 540     return trials.fmin(
#     541         fn,
#     542         space,
#     543         algo=algo,
#     544         max_evals=max_evals,
#     545         timeout=timeout,
#     546         loss_threshold=loss_threshold,
#     547         max_queue_len=max_queue_len,
#     548         rstate=rstate,
#     549         pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     550         verbose=verbose,
#     551         catch_eval_exceptions=catch_eval_exceptions,
#     552         return_argmin=return_argmin,
#     553         show_progressbar=show_progressbar,
#     554         early_stop_fn=early_stop_fn,
#     555         trials_save_file=trials_save_file,
#     556     )
#     558 if trials is None:
#     559     if os.path.exists(trials_save_file):
#
# File ~/anaconda3/envs/mlops/lib/python3.9/site-packages/hyperopt/base.py:671, in Trials.fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     666 # -- Stop-gap implementation!
#     667 #    fmin should have been a Trials method in the first place
#     668 #    but for now it's still sitting in another file.
#     669 from .fmin import fmin
# --> 671 return fmin(
#     672     fn,
#     673     space,
#     674     algo=algo,
#     675     max_evals=max_evals,
#     676     timeout=timeout,
#     677     loss_threshold=loss_threshold,
#     678     trials=self,
#     679     rstate=rstate,
#     680     verbose=verbose,
#     681     max_queue_len=max_queue_len,
#     682     allow_trials_fmin=False,  # -- prevent recursion
#     683     pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     684     catch_eval_exceptions=catch_eval_exceptions,
#     685     return_argmin=return_argmin,
#     686     show_progressbar=show_progressbar,
#     687     early_stop_fn=early_stop_fn,
#     688     trials_save_file=trials_save_file,
#     689 )
#
# File ~/anaconda3/envs/mlops/lib/python3.9/site-packages/hyperopt/fmin.py:586, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     583 rval.catch_eval_exceptions = catch_eval_exceptions
#     585 # next line is where the fmin is actually executed
# --> 586 rval.exhaust()
#     588 if return_argmin:
#     589     if len(trials.trials) == 0:
#
# File ~/anaconda3/envs/mlops/lib/python3.9/site-packages/hyperopt/fmin.py:364, in FMinIter.exhaust(self)
#     362 def exhaust(self):
#     363     n_done = len(self.trials)
# --> 364     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365     self.trials.refresh()
#     366     return self
#
# File ~/anaconda3/envs/mlops/lib/python3.9/site-packages/hyperopt/fmin.py:300, in FMinIter.run(self, N, block_until_done)
#     297     time.sleep(self.poll_interval_secs)
#     298 else:
#     299     # -- loop over trials and do the jobs directly
# --> 300     self.serial_evaluate()
#     302 self.trials.refresh()
#     303 if self.trials_save_file != "":
#
# File ~/anaconda3/envs/mlops/lib/python3.9/site-packages/hyperopt/fmin.py:178, in FMinIter.serial_evaluate(self, N)
#     176 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     177 try:
# --> 178     result = self.domain.evaluate(spec, ctrl)
#     179 except Exception as e:
#     180     logger.error("job exception: %s" % str(e))
#
# File ~/anaconda3/envs/mlops/lib/python3.9/site-packages/hyperopt/base.py:892, in Domain.evaluate(self, config, ctrl, attach_attachments)
#     883 else:
#     884     # -- the "work" of evaluating `config` can be written
#     885     #    either into the pyll part (self.expr)
#     886     #    or the normal Python part (self.fn)
#     887     pyll_rval = pyll.rec_eval(
#     888         self.expr,
#     889         memo=memo,
#     890         print_node_on_error=self.rec_eval_print_node_on_error,
#     891     )
# --> 892     rval = self.fn(pyll_rval)
#     894 if isinstance(rval, (float, int, np.number)):
#     895     dict_rval = {"loss": float(rval), "status": STATUS_OK}
#
# Cell In[20], line 5, in objective(params)
#       3 mlflow.set_tag("model", "xgboost")
#       4 mlflow.log_params(params)
# ----> 5 booster = xgb.train(
#       6     params=params,
#       7     dtrain=train,
#       8     num_boost_round=1000,
#       9     evals=[(valid, 'validation')],
#      10     early_stopping_rounds=50
#      11 )
#      12 y_pred = booster.predict(valid)
#      13 rmse = mean_squared_error(y_val, y_pred, squared=False)
#
# File ~/anaconda3/envs/mlops/lib/python3.9/site-packages/xgboost/core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~/anaconda3/envs/mlops/lib/python3.9/site-packages/xgboost/training.py:185, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     183 if cb_container.before_iteration(bst, i, dtrain, evals):
#     184     break
# --> 185 bst.update(dtrain, i, obj)
#     186 if cb_container.after_iteration(bst, i, dtrain, evals):
#     187     break
#
# File ~/anaconda3/envs/mlops/lib/python3.9/site-packages/xgboost/core.py:1918, in Booster.update(self, dtrain, iteration, fobj)
#    1915 self._validate_dmatrix_features(dtrain)
#    1917 if fobj is None:
# -> 1918     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1919                                             ctypes.c_int(iteration),
#    1920                                             dtrain.handle))
#    1921 else:
#    1922     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
mlflow.xgboost.autolog(disable=True)

# %%
with mlflow.start_run():
    
    train = xgb.DMatrix(X_train, label=y_train)
    valid = xgb.DMatrix(X_val, label=y_val)

    best_params = {
        'learning_rate': 0.19585355369315604,
        'max_depth': 17,
        'min_child_weight': 1.060597050922164,
        'objective': 'reg:linear',
        'reg_alpha': 0.018060244040060163,
        'reg_lambda': 0.011658731377413597,
        'seed': 42
    }

    mlflow.log_params(best_params)

    booster = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=1000,
        evals=[(valid, 'validation')],
        early_stopping_rounds=50
    )

    y_pred = booster.predict(valid)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    with open("models/preprocessor.b", "wb") as f_out:
        pickle.dump(dv, f_out)
    mlflow.log_artifact("models/lin_reg.bin", artifact_path="preprocessor")

    mlflow.xgboost.log_model(booster, artifact_path="models_mlflow/")
# Out:
# [09:43:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:17.73160
# [1]	validation-rmse:15.01971
# [2]	validation-rmse:12.91789
# [3]	validation-rmse:11.30505
# [4]	validation-rmse:10.08358
# [5]	validation-rmse:9.16700
# [6]	validation-rmse:8.48985
# [7]	validation-rmse:7.99279
# [8]	validation-rmse:7.62841
# [9]	validation-rmse:7.36121
# [10]	validation-rmse:7.16438
# [11]	validation-rmse:7.01963
# [12]	validation-rmse:6.91081
# [13]	validation-rmse:6.83111
# [14]	validation-rmse:6.76996
# [15]	validation-rmse:6.72372
# [16]	validation-rmse:6.68739
# [17]	validation-rmse:6.65848
# [18]	validation-rmse:6.63703
# [19]	validation-rmse:6.62027
# [20]	validation-rmse:6.60628
# [21]	validation-rmse:6.59642
# [22]	validation-rmse:6.58728
# [23]	validation-rmse:6.58184
# [24]	validation-rmse:6.57763
# [25]	validation-rmse:6.57287
# [26]	validation-rmse:6.56858
# [27]	validation-rmse:6.56466
# [28]	validation-rmse:6.56190
# [29]	validation-rmse:6.55910
# [30]	validation-rmse:6.55681
# [31]	validation-rmse:6.55490
# [32]	validation-rmse:6.55279
# [33]	validation-rmse:6.54900
# [34]	validation-rmse:6.54656
# [35]	validation-rmse:6.54384
# [36]	validation-rmse:6.54155
# [37]	validation-rmse:6.53973
# [38]	validation-rmse:6.53835
# [39]	validation-rmse:6.53680
# [40]	validation-rmse:6.53503
# [41]	validation-rmse:6.53389
# [42]	validation-rmse:6.53273
# [43]	validation-rmse:6.53151
# [44]	validation-rmse:6.52976
# [45]	validation-rmse:6.52826
# [46]	validation-rmse:6.52734
# [47]	validation-rmse:6.52532
# [48]	validation-rmse:6.52422
# [49]	validation-rmse:6.52310
# [50]	validation-rmse:6.52173
# [51]	validation-rmse:6.52070
# [52]	validation-rmse:6.51899
# [53]	validation-rmse:6.51813
# [54]	validation-rmse:6.51683
# [55]	validation-rmse:6.51563
# [56]	validation-rmse:6.51438
# [57]	validation-rmse:6.51270
# [58]	validation-rmse:6.51196
# [59]	validation-rmse:6.51125
# [60]	validation-rmse:6.50998
# [61]	validation-rmse:6.50914
# [62]	validation-rmse:6.50843
# [63]	validation-rmse:6.50795
# [64]	validation-rmse:6.50719
# [65]	validation-rmse:6.50593
# [66]	validation-rmse:6.50537
# [67]	validation-rmse:6.50430
# [68]	validation-rmse:6.50372
# [69]	validation-rmse:6.50329
# [70]	validation-rmse:6.50251
# [71]	validation-rmse:6.50037
# [72]	validation-rmse:6.49981
# [73]	validation-rmse:6.49879
# [74]	validation-rmse:6.49677
# [75]	validation-rmse:6.49408
# [76]	validation-rmse:6.49251
# [77]	validation-rmse:6.49135
# [78]	validation-rmse:6.49041
# [79]	validation-rmse:6.48963
# [80]	validation-rmse:6.48889
# [81]	validation-rmse:6.48859
# [82]	validation-rmse:6.48749
# [83]	validation-rmse:6.48672
# [84]	validation-rmse:6.48592
# [85]	validation-rmse:6.48505
# [86]	validation-rmse:6.48390
# [87]	validation-rmse:6.48327
# [88]	validation-rmse:6.48244
# [89]	validation-rmse:6.48178
# [90]	validation-rmse:6.48086
# [91]	validation-rmse:6.48013
# [92]	validation-rmse:6.47929
# [93]	validation-rmse:6.47801
# [94]	validation-rmse:6.47641
# [95]	validation-rmse:6.47535
# [96]	validation-rmse:6.47462
# [97]	validation-rmse:6.47383
# [98]	validation-rmse:6.47294
# [99]	validation-rmse:6.47241
# [100]	validation-rmse:6.47174
# [101]	validation-rmse:6.47103
# [102]	validation-rmse:6.47048
# [103]	validation-rmse:6.46958
# [104]	validation-rmse:6.46909
# [105]	validation-rmse:6.46764
# [106]	validation-rmse:6.46723
# [107]	validation-rmse:6.46659
# [108]	validation-rmse:6.46591
# [109]	validation-rmse:6.46532
# [110]	validation-rmse:6.46447
# [111]	validation-rmse:6.46359
# [112]	validation-rmse:6.46261
# [113]	validation-rmse:6.46176
# [114]	validation-rmse:6.46144
# [115]	validation-rmse:6.46044
# [116]	validation-rmse:6.45976
# [117]	validation-rmse:6.45882
# [118]	validation-rmse:6.45832
# [119]	validation-rmse:6.45778
# [120]	validation-rmse:6.45717
# [121]	validation-rmse:6.45630
# [122]	validation-rmse:6.45596
# [123]	validation-rmse:6.45534
# [124]	validation-rmse:6.45483
# [125]	validation-rmse:6.45431
# [126]	validation-rmse:6.45378
# [127]	validation-rmse:6.45306
# [128]	validation-rmse:6.45230
# [129]	validation-rmse:6.45226
# [130]	validation-rmse:6.45243
# [131]	validation-rmse:6.45204
# [132]	validation-rmse:6.45122
# [133]	validation-rmse:6.45106
# [134]	validation-rmse:6.45045
# [135]	validation-rmse:6.44973
# [136]	validation-rmse:6.44914
# [137]	validation-rmse:6.44853
# [138]	validation-rmse:6.44816
# [139]	validation-rmse:6.44763
# [140]	validation-rmse:6.44739
# [141]	validation-rmse:6.44748
# [142]	validation-rmse:6.44670
# [143]	validation-rmse:6.44616
# [144]	validation-rmse:6.44580
# [145]	validation-rmse:6.44530
# [146]	validation-rmse:6.44476
# [147]	validation-rmse:6.44389
# [148]	validation-rmse:6.44340
# [149]	validation-rmse:6.44285
# [150]	validation-rmse:6.44241
# [151]	validation-rmse:6.44172
# [152]	validation-rmse:6.44071
# [153]	validation-rmse:6.43979
# [154]	validation-rmse:6.43912
# [155]	validation-rmse:6.43822
# [156]	validation-rmse:6.43710
# [157]	validation-rmse:6.43674
# [158]	validation-rmse:6.43606
# [159]	validation-rmse:6.43564
# [160]	validation-rmse:6.43532
# [161]	validation-rmse:6.43484
# [162]	validation-rmse:6.43449
# [163]	validation-rmse:6.43422
# [164]	validation-rmse:6.43358
# [165]	validation-rmse:6.43323
# [166]	validation-rmse:6.43288
# [167]	validation-rmse:6.43207
# [168]	validation-rmse:6.43130
# [169]	validation-rmse:6.43106
# [170]	validation-rmse:6.43031
# [171]	validation-rmse:6.43000
# [172]	validation-rmse:6.42951
# [173]	validation-rmse:6.42904
# [174]	validation-rmse:6.42841
# [175]	validation-rmse:6.42781
# [176]	validation-rmse:6.42710
# [177]	validation-rmse:6.42657
# [178]	validation-rmse:6.42570
# [179]	validation-rmse:6.42525
# [180]	validation-rmse:6.42496
# [181]	validation-rmse:6.42469
# [182]	validation-rmse:6.42400
# [183]	validation-rmse:6.42347
# [184]	validation-rmse:6.42310
# [185]	validation-rmse:6.42216
# [186]	validation-rmse:6.42152
# [187]	validation-rmse:6.42060
# [188]	validation-rmse:6.42027
# [189]	validation-rmse:6.41948
# [190]	validation-rmse:6.41914
# [191]	validation-rmse:6.41838
# [192]	validation-rmse:6.41809
# [193]	validation-rmse:6.41756
# [194]	validation-rmse:6.41679
# [195]	validation-rmse:6.41654
# [196]	validation-rmse:6.41591
# [197]	validation-rmse:6.41531
# [198]	validation-rmse:6.41516
# [199]	validation-rmse:6.41464
# [200]	validation-rmse:6.41470
# [201]	validation-rmse:6.41379
# [202]	validation-rmse:6.41344
# [203]	validation-rmse:6.41259
# [204]	validation-rmse:6.41194
# [205]	validation-rmse:6.41130
# [206]	validation-rmse:6.41103
# [207]	validation-rmse:6.41029
# [208]	validation-rmse:6.40982
# [209]	validation-rmse:6.40964
# [210]	validation-rmse:6.40881
# [211]	validation-rmse:6.40856
# [212]	validation-rmse:6.40829
# [213]	validation-rmse:6.40789
# [214]	validation-rmse:6.40742
# [215]	validation-rmse:6.40663
# [216]	validation-rmse:6.40617
# [217]	validation-rmse:6.40582
# [218]	validation-rmse:6.40550
# [219]	validation-rmse:6.40514
# [220]	validation-rmse:6.40471
# [221]	validation-rmse:6.40431
# [222]	validation-rmse:6.40374
# [223]	validation-rmse:6.40330
# [224]	validation-rmse:6.40289
# [225]	validation-rmse:6.40230
# [226]	validation-rmse:6.40217
# [227]	validation-rmse:6.40181
# [228]	validation-rmse:6.40096
# [229]	validation-rmse:6.40074
# [230]	validation-rmse:6.40048
# [231]	validation-rmse:6.39994
# [232]	validation-rmse:6.39992
# [233]	validation-rmse:6.39967
# [234]	validation-rmse:6.39927
# [235]	validation-rmse:6.39876
# [236]	validation-rmse:6.39826
# [237]	validation-rmse:6.39803
# [238]	validation-rmse:6.39771
# [239]	validation-rmse:6.39763
# [240]	validation-rmse:6.39736
# [241]	validation-rmse:6.39725
# [242]	validation-rmse:6.39726
# [243]	validation-rmse:6.39701
# [244]	validation-rmse:6.39683
# [245]	validation-rmse:6.39658
# [246]	validation-rmse:6.39589
# [247]	validation-rmse:6.39529
# [248]	validation-rmse:6.39522
# [249]	validation-rmse:6.39495
# [250]	validation-rmse:6.39468
# [251]	validation-rmse:6.39422
# [252]	validation-rmse:6.39368
# [253]	validation-rmse:6.39334
# [254]	validation-rmse:6.39321
# [255]	validation-rmse:6.39321
# [256]	validation-rmse:6.39330
# [257]	validation-rmse:6.39332
# [258]	validation-rmse:6.39303
# [259]	validation-rmse:6.39275
# [260]	validation-rmse:6.39268
# [261]	validation-rmse:6.39211
# [262]	validation-rmse:6.39179
# [263]	validation-rmse:6.39154
# [264]	validation-rmse:6.39126
# [265]	validation-rmse:6.39099
# [266]	validation-rmse:6.39071
# [267]	validation-rmse:6.39007
# [268]	validation-rmse:6.38987
# [269]	validation-rmse:6.38961
# [270]	validation-rmse:6.38957
# [271]	validation-rmse:6.38936
# [272]	validation-rmse:6.38872
# [273]	validation-rmse:6.38768
# [274]	validation-rmse:6.38703
# [275]	validation-rmse:6.38660
# [276]	validation-rmse:6.38647
# [277]	validation-rmse:6.38613
# [278]	validation-rmse:6.38578
# [279]	validation-rmse:6.38555
# [280]	validation-rmse:6.38545
# [281]	validation-rmse:6.38521
# [282]	validation-rmse:6.38489
# [283]	validation-rmse:6.38476
# [284]	validation-rmse:6.38440
# [285]	validation-rmse:6.38421
# [286]	validation-rmse:6.38370
# [287]	validation-rmse:6.38329
# [288]	validation-rmse:6.38329
# [289]	validation-rmse:6.38291
# [290]	validation-rmse:6.38258
# [291]	validation-rmse:6.38202
# [292]	validation-rmse:6.38174
# [293]	validation-rmse:6.38136
# [294]	validation-rmse:6.38116
# [295]	validation-rmse:6.38057
# [296]	validation-rmse:6.38038
# [297]	validation-rmse:6.37968
# [298]	validation-rmse:6.37957
# [299]	validation-rmse:6.37937
# [300]	validation-rmse:6.37897
# [301]	validation-rmse:6.37874
# [302]	validation-rmse:6.37857
# [303]	validation-rmse:6.37846
# [304]	validation-rmse:6.37817
# [305]	validation-rmse:6.37800
# [306]	validation-rmse:6.37768
# [307]	validation-rmse:6.37741
# [308]	validation-rmse:6.37717
# [309]	validation-rmse:6.37691
# [310]	validation-rmse:6.37660
# [311]	validation-rmse:6.37636
# [312]	validation-rmse:6.37589
# [313]	validation-rmse:6.37546
# [314]	validation-rmse:6.37556
# [315]	validation-rmse:6.37505
# [316]	validation-rmse:6.37467
# [317]	validation-rmse:6.37424
# [318]	validation-rmse:6.37390
# [319]	validation-rmse:6.37329
# [320]	validation-rmse:6.37254
# [321]	validation-rmse:6.37249
# [322]	validation-rmse:6.37174
# [323]	validation-rmse:6.37151
# [324]	validation-rmse:6.37114
# [325]	validation-rmse:6.37095
# [326]	validation-rmse:6.37069
# [327]	validation-rmse:6.37036
# [328]	validation-rmse:6.37021
# [329]	validation-rmse:6.36996
# [330]	validation-rmse:6.36974
# [331]	validation-rmse:6.36930
# [332]	validation-rmse:6.36881
# [333]	validation-rmse:6.36868
# [334]	validation-rmse:6.36845
# [335]	validation-rmse:6.36794
# [336]	validation-rmse:6.36730
# [337]	validation-rmse:6.36721
# [338]	validation-rmse:6.36678
# [339]	validation-rmse:6.36681
# [340]	validation-rmse:6.36669
# [341]	validation-rmse:6.36650
# [342]	validation-rmse:6.36627
# [343]	validation-rmse:6.36602
# [344]	validation-rmse:6.36581
# [345]	validation-rmse:6.36514
# [346]	validation-rmse:6.36499
# [347]	validation-rmse:6.36430
# [348]	validation-rmse:6.36402
# [349]	validation-rmse:6.36377
# [350]	validation-rmse:6.36355
# [351]	validation-rmse:6.36328
# [352]	validation-rmse:6.36239
# [353]	validation-rmse:6.36219
# [354]	validation-rmse:6.36216
# [355]	validation-rmse:6.36203
# [356]	validation-rmse:6.36174
# [357]	validation-rmse:6.36150
# [358]	validation-rmse:6.36118
# [359]	validation-rmse:6.36066
# [360]	validation-rmse:6.36037
# [361]	validation-rmse:6.36020
# [362]	validation-rmse:6.35998
# [363]	validation-rmse:6.36010
# [364]	validation-rmse:6.35961
# [365]	validation-rmse:6.35930
# [366]	validation-rmse:6.35914
# [367]	validation-rmse:6.35895
# [368]	validation-rmse:6.35872
# [369]	validation-rmse:6.35848
# [370]	validation-rmse:6.35814
# [371]	validation-rmse:6.35791
# [372]	validation-rmse:6.35747
# [373]	validation-rmse:6.35718
# [374]	validation-rmse:6.35678
# [375]	validation-rmse:6.35684
# [376]	validation-rmse:6.35655
# [377]	validation-rmse:6.35630
# [378]	validation-rmse:6.35609
# [379]	validation-rmse:6.35581
# [380]	validation-rmse:6.35571
# [381]	validation-rmse:6.35524
# [382]	validation-rmse:6.35499
# [383]	validation-rmse:6.35488
# [384]	validation-rmse:6.35461
# [385]	validation-rmse:6.35456
# [386]	validation-rmse:6.35429
# [387]	validation-rmse:6.35350
# [388]	validation-rmse:6.35335
# [389]	validation-rmse:6.35313
# [390]	validation-rmse:6.35315
# [391]	validation-rmse:6.35300
# [392]	validation-rmse:6.35294
# [393]	validation-rmse:6.35286
# [394]	validation-rmse:6.35264
# [395]	validation-rmse:6.35251
# [396]	validation-rmse:6.35232
# [397]	validation-rmse:6.35217
# [398]	validation-rmse:6.35235
# [399]	validation-rmse:6.35222
# [400]	validation-rmse:6.35233
# [401]	validation-rmse:6.35223
# [402]	validation-rmse:6.35203
# [403]	validation-rmse:6.35125
# [404]	validation-rmse:6.35105
# [405]	validation-rmse:6.35088
# [406]	validation-rmse:6.35046
# [407]	validation-rmse:6.35029
# [408]	validation-rmse:6.35011
# [409]	validation-rmse:6.34987
# [410]	validation-rmse:6.34970
# [411]	validation-rmse:6.34974
# [412]	validation-rmse:6.34967
# [413]	validation-rmse:6.34950
# [414]	validation-rmse:6.34937
# [415]	validation-rmse:6.34923
# [416]	validation-rmse:6.34898
# [417]	validation-rmse:6.34890
# [418]	validation-rmse:6.34877
# [419]	validation-rmse:6.34890
# [420]	validation-rmse:6.34867
# [421]	validation-rmse:6.34841
# [422]	validation-rmse:6.34798
# [423]	validation-rmse:6.34763
# [424]	validation-rmse:6.34773
# [425]	validation-rmse:6.34759
# [426]	validation-rmse:6.34748
# [427]	validation-rmse:6.34738
# [428]	validation-rmse:6.34724
# [429]	validation-rmse:6.34725
# [430]	validation-rmse:6.34688
# [431]	validation-rmse:6.34620
# [432]	validation-rmse:6.34547
# [433]	validation-rmse:6.34535
# [434]	validation-rmse:6.34513
# [435]	validation-rmse:6.34494
# [436]	validation-rmse:6.34494
# [437]	validation-rmse:6.34438
# [438]	validation-rmse:6.34417
# [439]	validation-rmse:6.34390
# [440]	validation-rmse:6.34342
# [441]	validation-rmse:6.34325
# [442]	validation-rmse:6.34323
# [443]	validation-rmse:6.34300
# [444]	validation-rmse:6.34276
# [445]	validation-rmse:6.34230
# [446]	validation-rmse:6.34212
# [447]	validation-rmse:6.34195
# [448]	validation-rmse:6.34172
# [449]	validation-rmse:6.34151
# [450]	validation-rmse:6.34172
# [451]	validation-rmse:6.34158
# [452]	validation-rmse:6.34151
# [453]	validation-rmse:6.34145
# [454]	validation-rmse:6.34108
# [455]	validation-rmse:6.34067
# [456]	validation-rmse:6.34062
# [457]	validation-rmse:6.34033
# [458]	validation-rmse:6.34004
# [459]	validation-rmse:6.33996
# [460]	validation-rmse:6.34004
# [461]	validation-rmse:6.33995
# [462]	validation-rmse:6.33996
# [463]	validation-rmse:6.33992
# [464]	validation-rmse:6.33991
# [465]	validation-rmse:6.33971
# [466]	validation-rmse:6.33918
# [467]	validation-rmse:6.33890
# [468]	validation-rmse:6.33849
# [469]	validation-rmse:6.33854
# [470]	validation-rmse:6.33811
# [471]	validation-rmse:6.33790
# [472]	validation-rmse:6.33754
# [473]	validation-rmse:6.33758
# [474]	validation-rmse:6.33745
# [475]	validation-rmse:6.33735
# [476]	validation-rmse:6.33730
# [477]	validation-rmse:6.33726
# [478]	validation-rmse:6.33697
# [479]	validation-rmse:6.33686
# [480]	validation-rmse:6.33668
# [481]	validation-rmse:6.33669
# [482]	validation-rmse:6.33651
# [483]	validation-rmse:6.33674
# [484]	validation-rmse:6.33663
# [485]	validation-rmse:6.33633
# [486]	validation-rmse:6.33605
# [487]	validation-rmse:6.33562
# [488]	validation-rmse:6.33546
# [489]	validation-rmse:6.33547
# [490]	validation-rmse:6.33546
# [491]	validation-rmse:6.33552
# [492]	validation-rmse:6.33532
# [493]	validation-rmse:6.33522
# [494]	validation-rmse:6.33529
# [495]	validation-rmse:6.33511
# [496]	validation-rmse:6.33503
# [497]	validation-rmse:6.33486
# [498]	validation-rmse:6.33450
# [499]	validation-rmse:6.33445
# [500]	validation-rmse:6.33400
# [501]	validation-rmse:6.33396
# [502]	validation-rmse:6.33363
# [503]	validation-rmse:6.33323
# [504]	validation-rmse:6.33309
# [505]	validation-rmse:6.33281
# [506]	validation-rmse:6.33255
# [507]	validation-rmse:6.33246
# [508]	validation-rmse:6.33236
# [509]	validation-rmse:6.33220
# [510]	validation-rmse:6.33224
# [511]	validation-rmse:6.33197
# [512]	validation-rmse:6.33139
# [513]	validation-rmse:6.33114
# [514]	validation-rmse:6.33108
# [515]	validation-rmse:6.33084
# [516]	validation-rmse:6.33050
# [517]	validation-rmse:6.33048
# [518]	validation-rmse:6.33041
# [519]	validation-rmse:6.33013
# [520]	validation-rmse:6.32980
# [521]	validation-rmse:6.32974
# [522]	validation-rmse:6.32959
# [523]	validation-rmse:6.32951
# [524]	validation-rmse:6.32925
# [525]	validation-rmse:6.32905
# [526]	validation-rmse:6.32875
# [527]	validation-rmse:6.32843
# [528]	validation-rmse:6.32832
# [529]	validation-rmse:6.32796
# [530]	validation-rmse:6.32784
# [531]	validation-rmse:6.32771
# [532]	validation-rmse:6.32719
# [533]	validation-rmse:6.32696
# [534]	validation-rmse:6.32705
# [535]	validation-rmse:6.32721
# [536]	validation-rmse:6.32705
# [537]	validation-rmse:6.32686
# [538]	validation-rmse:6.32693
# [539]	validation-rmse:6.32677
# [540]	validation-rmse:6.32657
# [541]	validation-rmse:6.32665
# [542]	validation-rmse:6.32665
# [543]	validation-rmse:6.32641
# [544]	validation-rmse:6.32615
# [545]	validation-rmse:6.32608
# [546]	validation-rmse:6.32614
# [547]	validation-rmse:6.32601
# [548]	validation-rmse:6.32580
# [549]	validation-rmse:6.32556
# [550]	validation-rmse:6.32520
# [551]	validation-rmse:6.32505
# [552]	validation-rmse:6.32488
# [553]	validation-rmse:6.32470
# [554]	validation-rmse:6.32444
# [555]	validation-rmse:6.32418
# [556]	validation-rmse:6.32383
# [557]	validation-rmse:6.32361
# [558]	validation-rmse:6.32333
# [559]	validation-rmse:6.32322
# [560]	validation-rmse:6.32305
# [561]	validation-rmse:6.32291
# [562]	validation-rmse:6.32293
# [563]	validation-rmse:6.32271
# [564]	validation-rmse:6.32264
# [565]	validation-rmse:6.32258
# [566]	validation-rmse:6.32244
# [567]	validation-rmse:6.32227
# [568]	validation-rmse:6.32220
# [569]	validation-rmse:6.32222
# [570]	validation-rmse:6.32212
# [571]	validation-rmse:6.32201
# [572]	validation-rmse:6.32201
# [573]	validation-rmse:6.32197
# [574]	validation-rmse:6.32193
# [575]	validation-rmse:6.32187
# [576]	validation-rmse:6.32145
# [577]	validation-rmse:6.32114
# [578]	validation-rmse:6.32119
# [579]	validation-rmse:6.32112
# [580]	validation-rmse:6.32120
# [581]	validation-rmse:6.32123
# [582]	validation-rmse:6.32124
# [583]	validation-rmse:6.32133
# [584]	validation-rmse:6.32119
# [585]	validation-rmse:6.32119
# [586]	validation-rmse:6.32130
# [587]	validation-rmse:6.32107
# [588]	validation-rmse:6.32093
# [589]	validation-rmse:6.32064
# [590]	validation-rmse:6.32061
# [591]	validation-rmse:6.32049
# [592]	validation-rmse:6.32065
# [593]	validation-rmse:6.32036
# [594]	validation-rmse:6.32039
# [595]	validation-rmse:6.32015
# [596]	validation-rmse:6.32059
# [597]	validation-rmse:6.32060
# [598]	validation-rmse:6.32042
# [599]	validation-rmse:6.32036
# [600]	validation-rmse:6.32041
# [601]	validation-rmse:6.32056
# [602]	validation-rmse:6.32051
# [603]	validation-rmse:6.32062
# [604]	validation-rmse:6.32035
# [605]	validation-rmse:6.32053
# [606]	validation-rmse:6.32044
# [607]	validation-rmse:6.32035
# [608]	validation-rmse:6.32023
# [609]	validation-rmse:6.31982
# [610]	validation-rmse:6.31976
# [611]	validation-rmse:6.31956
# [612]	validation-rmse:6.31927
# [613]	validation-rmse:6.31915
# [614]	validation-rmse:6.31911
# [615]	validation-rmse:6.31899
# [616]	validation-rmse:6.31886
# [617]	validation-rmse:6.31839
# [618]	validation-rmse:6.31837
# [619]	validation-rmse:6.31833
# [620]	validation-rmse:6.31827
# [621]	validation-rmse:6.31832
# [622]	validation-rmse:6.31775
# [623]	validation-rmse:6.31758
# [624]	validation-rmse:6.31740
# [625]	validation-rmse:6.31736
# [626]	validation-rmse:6.31712
# [627]	validation-rmse:6.31704
# [628]	validation-rmse:6.31698
# [629]	validation-rmse:6.31681
# [630]	validation-rmse:6.31664
# [631]	validation-rmse:6.31652
# [632]	validation-rmse:6.31642
# [633]	validation-rmse:6.31651
# [634]	validation-rmse:6.31657
# [635]	validation-rmse:6.31654
# [636]	validation-rmse:6.31644
# [637]	validation-rmse:6.31658
# [638]	validation-rmse:6.31640
# [639]	validation-rmse:6.31629
# [640]	validation-rmse:6.31606
# [641]	validation-rmse:6.31589
# [642]	validation-rmse:6.31575
# [643]	validation-rmse:6.31555
# [644]	validation-rmse:6.31539
# [645]	validation-rmse:6.31523
# [646]	validation-rmse:6.31491
# [647]	validation-rmse:6.31489
# [648]	validation-rmse:6.31459
# [649]	validation-rmse:6.31460
# [650]	validation-rmse:6.31445
# [651]	validation-rmse:6.31432
# [652]	validation-rmse:6.31436
# [653]	validation-rmse:6.31410
# [654]	validation-rmse:6.31372
# [655]	validation-rmse:6.31368
# [656]	validation-rmse:6.31348
# [657]	validation-rmse:6.31337
# [658]	validation-rmse:6.31324
# [659]	validation-rmse:6.31303
# [660]	validation-rmse:6.31293
# [661]	validation-rmse:6.31270
# [662]	validation-rmse:6.31272
# [663]	validation-rmse:6.31242
# [664]	validation-rmse:6.31228
# [665]	validation-rmse:6.31219
# [666]	validation-rmse:6.31201
# [667]	validation-rmse:6.31201
# [668]	validation-rmse:6.31231
# [669]	validation-rmse:6.31225
# [670]	validation-rmse:6.31235
# [671]	validation-rmse:6.31236
# [672]	validation-rmse:6.31218
# [673]	validation-rmse:6.31212
# [674]	validation-rmse:6.31207
# [675]	validation-rmse:6.31196
# [676]	validation-rmse:6.31186
# [677]	validation-rmse:6.31196
# [678]	validation-rmse:6.31175
# [679]	validation-rmse:6.31200
# [680]	validation-rmse:6.31208
# [681]	validation-rmse:6.31219
# [682]	validation-rmse:6.31201
# [683]	validation-rmse:6.31174
# [684]	validation-rmse:6.31163
# [685]	validation-rmse:6.31176
# [686]	validation-rmse:6.31160
# [687]	validation-rmse:6.31174
# [688]	validation-rmse:6.31162
# [689]	validation-rmse:6.31127
# [690]	validation-rmse:6.31109
# [691]	validation-rmse:6.31081
# [692]	validation-rmse:6.31077
# [693]	validation-rmse:6.31044
# [694]	validation-rmse:6.31040
# [695]	validation-rmse:6.31039
# [696]	validation-rmse:6.31029
# [697]	validation-rmse:6.31003
# [698]	validation-rmse:6.31003
# [699]	validation-rmse:6.31064
# [700]	validation-rmse:6.31062
# [701]	validation-rmse:6.31060
# [702]	validation-rmse:6.31047
# [703]	validation-rmse:6.31060
# [704]	validation-rmse:6.31046
# [705]	validation-rmse:6.31045
# [706]	validation-rmse:6.31029
# [707]	validation-rmse:6.31033
# [708]	validation-rmse:6.31017
# [709]	validation-rmse:6.31022
# [710]	validation-rmse:6.31017
# [711]	validation-rmse:6.30986
# [712]	validation-rmse:6.30984
# [713]	validation-rmse:6.30985
# [714]	validation-rmse:6.30962
# [715]	validation-rmse:6.30950
# [716]	validation-rmse:6.30912
# [717]	validation-rmse:6.30876
# [718]	validation-rmse:6.30887
# [719]	validation-rmse:6.30899
# [720]	validation-rmse:6.30899
# [721]	validation-rmse:6.30894
# [722]	validation-rmse:6.30869
# [723]	validation-rmse:6.30843
# [724]	validation-rmse:6.30829
# [725]	validation-rmse:6.30827
# [726]	validation-rmse:6.30817
# [727]	validation-rmse:6.30796
# [728]	validation-rmse:6.30781
# [729]	validation-rmse:6.30763
# [730]	validation-rmse:6.30742
# [731]	validation-rmse:6.30715
# [732]	validation-rmse:6.30707
# [733]	validation-rmse:6.30637
# [734]	validation-rmse:6.30659
# [735]	validation-rmse:6.30628
# [736]	validation-rmse:6.30603
# [737]	validation-rmse:6.30620
# [738]	validation-rmse:6.30624
# [739]	validation-rmse:6.30611
# [740]	validation-rmse:6.30599
# [741]	validation-rmse:6.30540
# [742]	validation-rmse:6.30533
# [743]	validation-rmse:6.30524
# [744]	validation-rmse:6.30521
# [745]	validation-rmse:6.30524
# [746]	validation-rmse:6.30501
# [747]	validation-rmse:6.30487
# [748]	validation-rmse:6.30483
# [749]	validation-rmse:6.30487
# [750]	validation-rmse:6.30474
# [751]	validation-rmse:6.30466
# [752]	validation-rmse:6.30463
# [753]	validation-rmse:6.30448
# [754]	validation-rmse:6.30441
# [755]	validation-rmse:6.30460
# [756]	validation-rmse:6.30449
# [757]	validation-rmse:6.30432
# [758]	validation-rmse:6.30407
# [759]	validation-rmse:6.30433
# [760]	validation-rmse:6.30419
# [761]	validation-rmse:6.30405
# [762]	validation-rmse:6.30404
# [763]	validation-rmse:6.30406
# [764]	validation-rmse:6.30426
# [765]	validation-rmse:6.30436
# [766]	validation-rmse:6.30465
# [767]	validation-rmse:6.30436
# [768]	validation-rmse:6.30421
# [769]	validation-rmse:6.30422
# [770]	validation-rmse:6.30405
# [771]	validation-rmse:6.30376
# [772]	validation-rmse:6.30404
# [773]	validation-rmse:6.30405
# [774]	validation-rmse:6.30388
# [775]	validation-rmse:6.30387
# [776]	validation-rmse:6.30388
# [777]	validation-rmse:6.30376
# [778]	validation-rmse:6.30363
# [779]	validation-rmse:6.30363
# [780]	validation-rmse:6.30372
# [781]	validation-rmse:6.30375
# [782]	validation-rmse:6.30374
# [783]	validation-rmse:6.30380
# [784]	validation-rmse:6.30378
# [785]	validation-rmse:6.30370
# [786]	validation-rmse:6.30376
# [787]	validation-rmse:6.30382
# [788]	validation-rmse:6.30414
# [789]	validation-rmse:6.30414
# [790]	validation-rmse:6.30335
# [791]	validation-rmse:6.30352
# [792]	validation-rmse:6.30336
# [793]	validation-rmse:6.30331
# [794]	validation-rmse:6.30322
# [795]	validation-rmse:6.30321
# [796]	validation-rmse:6.30337
# [797]	validation-rmse:6.30331
# [798]	validation-rmse:6.30335
# [799]	validation-rmse:6.30323
# [800]	validation-rmse:6.30326
# [801]	validation-rmse:6.30302
# [802]	validation-rmse:6.30295
# [803]	validation-rmse:6.30293
# [804]	validation-rmse:6.30292
# [805]	validation-rmse:6.30293
# [806]	validation-rmse:6.30300
# [807]	validation-rmse:6.30291
# [808]	validation-rmse:6.30289
# [809]	validation-rmse:6.30293
# [810]	validation-rmse:6.30280
# [811]	validation-rmse:6.30268
# [812]	validation-rmse:6.30251
# [813]	validation-rmse:6.30235
# [814]	validation-rmse:6.30246
# [815]	validation-rmse:6.30241
# [816]	validation-rmse:6.30256
# [817]	validation-rmse:6.30253
# [818]	validation-rmse:6.30236
# [819]	validation-rmse:6.30221
# [820]	validation-rmse:6.30204
# [821]	validation-rmse:6.30197
# [822]	validation-rmse:6.30180
# [823]	validation-rmse:6.30183
# [824]	validation-rmse:6.30155
# [825]	validation-rmse:6.30145
# [826]	validation-rmse:6.30166
# [827]	validation-rmse:6.30164
# [828]	validation-rmse:6.30161
# [829]	validation-rmse:6.30167
# [830]	validation-rmse:6.30164
# [831]	validation-rmse:6.30190
# [832]	validation-rmse:6.30196
# [833]	validation-rmse:6.30166
# [834]	validation-rmse:6.30168
# [835]	validation-rmse:6.30152
# [836]	validation-rmse:6.30121
# [837]	validation-rmse:6.30120
# [838]	validation-rmse:6.30097
# [839]	validation-rmse:6.30091
# [840]	validation-rmse:6.30066
# [841]	validation-rmse:6.30063
# [842]	validation-rmse:6.30046
# [843]	validation-rmse:6.30033
# [844]	validation-rmse:6.30021
# [845]	validation-rmse:6.30045
# [846]	validation-rmse:6.30037
# [847]	validation-rmse:6.30047
# [848]	validation-rmse:6.29986
# [849]	validation-rmse:6.29972
# [850]	validation-rmse:6.29971
# [851]	validation-rmse:6.29966
# [852]	validation-rmse:6.29958
# [853]	validation-rmse:6.29931
# [854]	validation-rmse:6.29929
# [855]	validation-rmse:6.29946
# [856]	validation-rmse:6.29958
# [857]	validation-rmse:6.29963
# [858]	validation-rmse:6.29968
# [859]	validation-rmse:6.29975
# [860]	validation-rmse:6.29993
# [861]	validation-rmse:6.30021
# [862]	validation-rmse:6.30019
# [863]	validation-rmse:6.30039
# [864]	validation-rmse:6.30037
# [865]	validation-rmse:6.30033
# [866]	validation-rmse:6.30021
# [867]	validation-rmse:6.30022
# [868]	validation-rmse:6.30023
# [869]	validation-rmse:6.30029
# [870]	validation-rmse:6.30026
# [871]	validation-rmse:6.30019
# [872]	validation-rmse:6.30013
# [873]	validation-rmse:6.29997
# [874]	validation-rmse:6.29993
# [875]	validation-rmse:6.29977
# [876]	validation-rmse:6.29954
# [877]	validation-rmse:6.29938
# [878]	validation-rmse:6.29926
# [879]	validation-rmse:6.29912
# [880]	validation-rmse:6.29904
# [881]	validation-rmse:6.29899
# [882]	validation-rmse:6.29888
# [883]	validation-rmse:6.29896
# [884]	validation-rmse:6.29898
# [885]	validation-rmse:6.29900
# [886]	validation-rmse:6.29918
# [887]	validation-rmse:6.29919
# [888]	validation-rmse:6.29917
# [889]	validation-rmse:6.29921
# [890]	validation-rmse:6.29914
# [891]	validation-rmse:6.29910
# [892]	validation-rmse:6.29918
# [893]	validation-rmse:6.29927
# [894]	validation-rmse:6.29945
# [895]	validation-rmse:6.29947
# [896]	validation-rmse:6.29938
# [897]	validation-rmse:6.29930
# [898]	validation-rmse:6.29937
# [899]	validation-rmse:6.29947
# [900]	validation-rmse:6.29967
# [901]	validation-rmse:6.29951
# [902]	validation-rmse:6.29939
# [903]	validation-rmse:6.29963
# [904]	validation-rmse:6.29955
# [905]	validation-rmse:6.29960
# [906]	validation-rmse:6.29955
# [907]	validation-rmse:6.29942
# [908]	validation-rmse:6.29944
# [909]	validation-rmse:6.29935
# [910]	validation-rmse:6.29942
# [911]	validation-rmse:6.29952
# [912]	validation-rmse:6.29963
# [913]	validation-rmse:6.29935
# [914]	validation-rmse:6.29928
# [915]	validation-rmse:6.29904
# [916]	validation-rmse:6.29893
# [917]	validation-rmse:6.29899
# [918]	validation-rmse:6.29896
# [919]	validation-rmse:6.29925
# [920]	validation-rmse:6.29908
# [921]	validation-rmse:6.29898
# [922]	validation-rmse:6.29894
# [923]	validation-rmse:6.29916
# [924]	validation-rmse:6.29899
# [925]	validation-rmse:6.29875
# [926]	validation-rmse:6.29864
# [927]	validation-rmse:6.29860
# [928]	validation-rmse:6.29872
# [929]	validation-rmse:6.29857
# [930]	validation-rmse:6.29850
# [931]	validation-rmse:6.29831
# [932]	validation-rmse:6.29801
# [933]	validation-rmse:6.29800
# [934]	validation-rmse:6.29823
# [935]	validation-rmse:6.29803
# [936]	validation-rmse:6.29791
# [937]	validation-rmse:6.29791
# [938]	validation-rmse:6.29794
# [939]	validation-rmse:6.29788
# [940]	validation-rmse:6.29796
# [941]	validation-rmse:6.29758
# [942]	validation-rmse:6.29811
# [943]	validation-rmse:6.29807
# [944]	validation-rmse:6.29802
# [945]	validation-rmse:6.29799
# [946]	validation-rmse:6.29800
# [947]	validation-rmse:6.29789
# [948]	validation-rmse:6.29788
# [949]	validation-rmse:6.29798
# [950]	validation-rmse:6.29791
# [951]	validation-rmse:6.29778
# [952]	validation-rmse:6.29766
# [953]	validation-rmse:6.29747
# [954]	validation-rmse:6.29749
# [955]	validation-rmse:6.29764
# [956]	validation-rmse:6.29759
# [957]	validation-rmse:6.29751
# [958]	validation-rmse:6.29749
# [959]	validation-rmse:6.29749
# [960]	validation-rmse:6.29743
# [961]	validation-rmse:6.29745
# [962]	validation-rmse:6.29726
# [963]	validation-rmse:6.29610
# [964]	validation-rmse:6.29606
# [965]	validation-rmse:6.29610
# [966]	validation-rmse:6.29597
# [967]	validation-rmse:6.29594
# [968]	validation-rmse:6.29601
# [969]	validation-rmse:6.29610
# [970]	validation-rmse:6.29607
# [971]	validation-rmse:6.29600
# [972]	validation-rmse:6.29585
# [973]	validation-rmse:6.29526
# [974]	validation-rmse:6.29531
# [975]	validation-rmse:6.29539
# [976]	validation-rmse:6.29525
# [977]	validation-rmse:6.29529
# [978]	validation-rmse:6.29528
# [979]	validation-rmse:6.29519
# [980]	validation-rmse:6.29534
# [981]	validation-rmse:6.29563
# [982]	validation-rmse:6.29576
# [983]	validation-rmse:6.29569
# [984]	validation-rmse:6.29566
# [985]	validation-rmse:6.29549
# [986]	validation-rmse:6.29566
# [987]	validation-rmse:6.29570
# [988]	validation-rmse:6.29562
# [989]	validation-rmse:6.29542
# [990]	validation-rmse:6.29502
# [991]	validation-rmse:6.29391
# [992]	validation-rmse:6.29393
# [993]	validation-rmse:6.29401
# [994]	validation-rmse:6.29403
# [995]	validation-rmse:6.29403
# [996]	validation-rmse:6.29429
# [997]	validation-rmse:6.29427
# [998]	validation-rmse:6.29425
# [999]	validation-rmse:6.29412
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 32
#      30 with open("models/preprocessor.b", "wb") as f_out:
#      31     pickle.dump(dv, f_out)
# ---> 32 mlflow.log_artifact("models/ling_reg.bin", artifact_path="preprocessor")
#      34 mlflow.xgboost.log_model(booster, artifact_path="models_mlflow/")
#
# File ~/anaconda3/envs/mlops/lib/python3.9/site-packages/mlflow/tracking/fluent.py:784, in log_artifact(local_path, artifact_path)
#     761 """
#     762 Log a local file or directory as an artifact of the currently active run. If no run is
#     763 active, this method will create a new active run.
#    (...)
#     781         mlflow.log_artifact("features.txt")
#     782 """
#     783 run_id = _get_or_start_run().info.run_id
# --> 784 MlflowClient().log_artifact(run_id, local_path, artifact_path)
#
# File ~/anaconda3/envs/mlops/lib/python3.9/site-packages/mlflow/tracking/client.py:1028, in MlflowClient.log_artifact(self, run_id, local_path, artifact_path)
#     993 def log_artifact(self, run_id, local_path, artifact_path=None) -> None:
#     994     """
#     995     Write a local file or directory to the remote ``artifact_uri``.
#     996
#    (...)
#    1026         is_dir: False
#    1027     """
# -> 1028     self._tracking_client.log_artifact(run_id, local_path, artifact_path)
#
# File ~/anaconda3/envs/mlops/lib/python3.9/site-packages/mlflow/tracking/_tracking_service/client.py:439, in TrackingServiceClient.log_artifact(self, run_id, local_path, artifact_path)
#     437     artifact_repo.log_artifacts(local_path, path_name)
#     438 else:
# --> 439     artifact_repo.log_artifact(local_path, artifact_path)
#
# File ~/anaconda3/envs/mlops/lib/python3.9/site-packages/mlflow/store/artifact/local_artifact_repo.py:38, in LocalArtifactRepository.log_artifact(self, local_file, artifact_path)
#      36 if not os.path.exists(artifact_dir):
#      37     mkdir(artifact_dir)
# ---> 38 shutil.copyfile(local_file, os.path.join(artifact_dir, os.path.basename(local_file)))
#
# File ~/anaconda3/envs/mlops/lib/python3.9/shutil.py:264, in copyfile(src, dst, follow_symlinks)
#     262     os.symlink(os.readlink(src), dst)
#     263 else:
# --> 264     with open(src, 'rb') as fsrc:
#     265         try:
#     266             with open(dst, 'wb') as fdst:
#     267                 # macOS
#
# FileNotFoundError: [Errno 2] No such file or directory: 'models/ling_reg.bin'

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.svm import LinearSVR

mlflow.sklearn.autolog()

for model_class in (RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor, LinearSVR):

    with mlflow.start_run():

        mlflow.log_param("train-data-path", "./data/green_tripdata_2021-01.csv")
        mlflow.log_param("valid-data-path", "./data/green_tripdata_2021-02.csv")
        mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

        mlmodel = model_class()
        mlmodel.fit(X_train, y_train)

        y_pred = mlmodel.predict(X_val)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)
# Out:
# /Users/cristian.martinez/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
